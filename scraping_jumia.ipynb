# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_50808\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
product_data = pd.read_csv('jumia_products.csv')
product_data.head()
# Out:
#                                            Item name Current price  Old price  \
# 0  NIVEA Perfect & Radiant Even Tone Day And Nigh...       KSh 999  KSh 1,560
# 1  NIVEA Radiant & Beauty Advanced Care Lotion Fo...       KSh 949  KSh 1,460
# 2  NIVEA Nourishing Cocoa Body Lotion With Cocoa ...     KSh 1,174  KSh 1,302
# 3  NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...       KSh 728  KSh 1,040
# 4  NIVEA MEN Deep Antibacterial Anti-Perspirant R...       KSh 728  KSh 1,040
#
#   Discount                                               Link
# 0      36%  /nivea-perfect-radiant-even-tone-day-and-night...
# 1      35%  /nivea-radiant-beauty-advanced-care-lotion-for...
# 2      10%  /nivea-nourishing-cocoa-body-lotion-with-cocoa...
# 3      30%  /nivea-pearl-beauty-anti-perspirant-rollon-48h...
# 4      30%  /nivea-men-deep-antibacterial-anti-perspirant-...

# %%
items_df = pd.DataFrame(records, columns=['Item_name', 'Current_price', 'Old_price', 'Discount', 'Link'])
items_df.head(50)
# Out:
#                                             Item_name           Current_price  \
# 0   NIVEA Perfect & Radiant Even Tone Day And Nigh...                 KSh 999
# 1   NIVEA Radiant & Beauty Advanced Care Lotion Fo...                 KSh 949
# 2   NIVEA Nourishing Cocoa Body Lotion With Cocoa ...               KSh 1,174
# 3   NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...                 KSh 728
# 4   NIVEA MEN Deep Antibacterial Anti-Perspirant R...                 KSh 728
# 5   NIVEA Pearl & Beauty Black Pearl Fine Fragranc...                 KSh 728
# 6   NIVEA Perfect & Radiant Luminous630 Anti Dark ...               KSh 3,647
# 7   NIVEA Perfect & Radiant Even Tone Day Cream SP...                 KSh 585
# 8   NIVEA Q10 Power Anti-Wrinkle Day Cream 50ml & ...               KSh 2,496
# 9   Epson EcoTank L3250 A4 WIRELESS Printer (All-i...              KSh 27,999
# 10                       Pembe Pembe Maize Meal – 5Kg                 KSh 361
# ...

# %%
items_df.dropna(inplace=True)
items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1686 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item_name      1686 non-null   object
#  1   Current_price  1686 non-null   object
#  2   Old_price      1686 non-null   object
#  3   Discount       1686 non-null   object
#  4   Link           1686 non-null   object
# dtypes: object(5)
# memory usage: 79.0+ KB

# %%
# changin discount column to float
def change_disc_col(df):
    df['Discount'] = df['Discount'].str.replace('%','')
    df['Discount'] = df['Discount'].astype(float)
    return df.info()

change_disc_col(items_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1686 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item_name      1686 non-null   object
#  1   Current_price  1686 non-null   object
#  2   Old_price      1686 non-null   object
#  3   Discount       1686 non-null   float64
#  4   Link           1686 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 79.0+ KB

# %%
# filtering out prices that have a range
range_items = items_df[items_df['Current_price'].str.contains('-') | items_df['Old_price'].str.contains('-')]
# removing the rows from the original dataset
new_items_df = items_df.drop(range_items.index)
new_items_df
# Out:
#                                               Item_name Current_price  \
# 0     NIVEA Perfect & Radiant Even Tone Day And Nigh...       KSh 999
# 1     NIVEA Radiant & Beauty Advanced Care Lotion Fo...       KSh 949
# 2     NIVEA Nourishing Cocoa Body Lotion With Cocoa ...     KSh 1,174
# 3     NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...       KSh 728
# 4     NIVEA MEN Deep Antibacterial Anti-Perspirant R...       KSh 728
# ...                                                 ...           ...
# 1994  Fashion 【 PU - Brown  】 Mens Official Shoes Me...     KSh 2,750
# 1995  5V 3A Charger Head Digital Display High Compat...       KSh 464
# 1996  UV LED Nail Dryer/Gel Machine For Manicure And...     KSh 2,750
# 1997  Mikasa Size 5 Soccer Ball  Red & White Plus A ...     KSh 1,699
# 1999  2PCS  Universal Breathable Ultra-thin Game Con...        KSh 85
#
#       Old_price  Discount                                               Link
# ...

# %%
range_items
# Out:
#                                               Item_name  \
# 52    Neoprene  Corset Belt Body Shaper Slimming Shaper
# 78      Kojic Acid Soap Body Skin Lightening Soap- 3pcs
# 96      Kojic Acid Soap Body Skin Lightening Soap- 3pcs
# 99         Fashion Unisex Black Warm Jacket Casual Coat
# 133   Crease Guard Shoe Protector Sneakers Toe Caps ...
# ...                                                 ...
# 1966               Fashion Satin Sleep Bonnet Sleep Cap
# 1985  Fashion Black Soft Khaki Trouser Stretch Slim ...
# 1991          Cream Curtains 2Pc 1.5M Each + FREE SHEER
# 1993           Fashion 2-Piece Suit/Short Sleeved Shirt
# 1998                Snail Collagen Soothing Gel - 300ml
#
#               Current_price              Old_price  Discount  \
# 52    KSh 1,477 - KSh 1,586  KSh 1,773 - KSh 2,379      33.0
# 78        KSh 320 - KSh 923    KSh 320 - KSh 1,200      46.0
# 96        KSh 320 - KSh 923    KSh 320 - KSh 1,200      46.0
# ...

# %%
split_values = range_items['Current_price'].str.split('-', expand=True)
range_items.loc[:, 'price_start_value'] = split_values[0].str.strip()
range_items.loc[:, 'price_end_value'] = split_values[1].str.strip()
range_items['price_end_value'].fillna(range_items['price_start_value'], inplace=True)

range_items
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_61324\2832191318.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   range_items.loc[:, 'price_start_value'] = split_values[0].str.strip()
# C:\Users\Dell\AppData\Local\Temp\ipykernel_61324\2832191318.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   range_items.loc[:, 'price_end_value'] = split_values[1].str.strip()
# ...

# %%
split_values = range_items['Old_price'].str.split('-', expand=True)
range_items.loc[:, 'old_price_start_value'] = split_values[0].str.strip()
range_items.loc[:, 'old_price_end_value'] = split_values[1].str.strip()
range_items['old_price_end_value'].fillna(range_items['old_price_start_value'], inplace=True)

range_items
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_61324\4095780832.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   range_items.loc[:, 'old_price_start_value'] = split_values[0].str.strip()
# C:\Users\Dell\AppData\Local\Temp\ipykernel_61324\4095780832.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   range_items.loc[:, 'old_price_end_value'] = split_values[1].str.strip()
# ...

# %%
range_items.drop(['Current_price', 'Old_price'], axis = 1, inplace=True)
range_items
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_61324\2308283458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   range_items.drop(['Current_price', 'Old_price'], axis = 1, inplace=True)
#                                               Item_name  Discount  \
# 52    Neoprene  Corset Belt Body Shaper Slimming Shaper      33.0
# 78      Kojic Acid Soap Body Skin Lightening Soap- 3pcs      46.0
# 96      Kojic Acid Soap Body Skin Lightening Soap- 3pcs      46.0
# 99         Fashion Unisex Black Warm Jacket Casual Coat      30.0
# 133   Crease Guard Shoe Protector Sneakers Toe Caps ...      42.0
# ...                                                 ...       ...
# 1966               Fashion Satin Sleep Bonnet Sleep Cap      25.0
# 1985  Fashion Black Soft Khaki Trouser Stretch Slim ...      20.0
# ...

# %%
range_items['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Dell\Desktop\jumia_project\jumia_project_venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 range_items['']
#
# ...
