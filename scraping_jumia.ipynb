# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
product_data = pd.read_csv('jumia_products.csv')
product_data.head(10)
# Out:
#                                            Item name Current price  \
# 0  NIVEA Perfect & Radiant Even Tone Day And Nigh...       KSh 999
# 1  NIVEA Radiant & Beauty Advanced Care Lotion Fo...       KSh 949
# 2  NIVEA Nourishing Cocoa Body Lotion With Cocoa ...     KSh 1,174
# 3  NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...       KSh 728
# 4  NIVEA MEN Deep Antibacterial Anti-Perspirant R...       KSh 728
# 5  NIVEA Pearl & Beauty Black Pearl Fine Fragranc...       KSh 728
# 6  NIVEA Perfect & Radiant Luminous630 Anti Dark ...     KSh 3,647
# 7  NIVEA Perfect & Radiant Even Tone Day Cream SP...       KSh 585
# 8  NIVEA Q10 Power Anti-Wrinkle Day Cream 50ml & ...     KSh 2,496
# 9  Epson EcoTank L3250 A4 WIRELESS Printer (All-i...    KSh 33,999
#
#     Old price Discount                                               Link
# 0   KSh 1,560      36%  /nivea-perfect-radiant-even-tone-day-and-night...
# 1   KSh 1,460      35%  /nivea-radiant-beauty-advanced-care-lotion-for...
# 2   KSh 1,302      10%  /nivea-nourishing-cocoa-body-lotion-with-cocoa...
# 3   KSh 1,040      30%  /nivea-pearl-beauty-anti-perspirant-rollon-48h...
# 4   KSh 1,040      30%  /nivea-men-deep-antibacterial-anti-perspirant-...
# 5   KSh 1,040      30%  /nivea-pearl-beauty-black-pearl-fine-fragrance...
# 6   KSh 5,610      35%  /nivea-perfect-radiant-luminous630-anti-dark-m...
# 7     KSh 780      25%  /nivea-perfect-radiant-even-tone-day-cream-spf...
# 8   KSh 3,840      35%  /nivea-q10-power-anti-wrinkle-day-cream-50ml-n...
# 9  KSh 38,000      11%  /epson-ecotank-l3250-a4-wireless-printer-all-i...

# %%
product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1705 non-null   object
#  1   Current price  1705 non-null   object
#  2   Old price      1705 non-null   object
#  3   Discount       1705 non-null   object
#  4   Link           1705 non-null   object
# dtypes: object(5)
# memory usage: 66.7+ KB

# %% [markdown]
# ## Data cleaning

# %%
# changin discount column to float
def change_disc_col(df):
    df['Discount'] = df['Discount'].str.replace('%','')
    df['Discount'] = df['Discount'].astype(float)
    return df.info()

change_disc_col(product_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1705 non-null   object
#  1   Current price  1705 non-null   object
#  2   Old price      1705 non-null   object
#  3   Discount       1705 non-null   float64
#  4   Link           1705 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 66.7+ KB

# %%
# filtering out prices that have a range
ranged_items = product_data[product_data['Current price'].str.contains('-') | product_data['Old price'].str.contains('-')].copy()
# removing the rows from the original dataset
new_product_data = product_data.drop(ranged_items.index)
new_product_data
# Out:
#                                               Item name Current price  \
# 0     NIVEA Perfect & Radiant Even Tone Day And Nigh...       KSh 999
# 1     NIVEA Radiant & Beauty Advanced Care Lotion Fo...       KSh 949
# 2     NIVEA Nourishing Cocoa Body Lotion With Cocoa ...     KSh 1,174
# 3     NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...       KSh 728
# 4     NIVEA MEN Deep Antibacterial Anti-Perspirant R...       KSh 728
# ...                                                 ...           ...
# 1700  MK TV Guard Voltage Protector For Digital Smar...     KSh 1,150
# 1701  Kinbar High Quality Alarm Padlock Siren Alarm ...     KSh 1,999
# 1702                                   HOMMY 3D CARPETS     KSh 4,000
# 1703  Canon GI-490 Black Ink Bottle +FREE EXECUTIVE PEN     KSh 1,999
# 1704               Guanjing Turmeric Natural Face Serum       KSh 340
#
#       Old price  Discount                                               Link
# 0     KSh 1,560      36.0  /nivea-perfect-radiant-even-tone-day-and-night...
# 1     KSh 1,460      35.0  /nivea-radiant-beauty-advanced-care-lotion-for...
# 2     KSh 1,302      10.0  /nivea-nourishing-cocoa-body-lotion-with-cocoa...
# 3     KSh 1,040      30.0  /nivea-pearl-beauty-anti-perspirant-rollon-48h...
# 4     KSh 1,040      30.0  /nivea-men-deep-antibacterial-anti-perspirant-...
# ...         ...       ...                                                ...
# 1700  KSh 2,000      43.0  /mk-tv-guard-voltage-protector-for-digital-sma...
# 1701  KSh 3,500      43.0  /kinbar-high-quality-alarm-padlock-siren-alarm...
# 1702  KSh 6,000      33.0                   /hommy-3d-carpets-123400646.html
# 1703  KSh 3,000      33.0  /canon-gi-490-black-ink-bottle-free-executive-...
# 1704    KSh 550      38.0  /guanjing-turmeric-natural-face-serum-12339460...
#
# [1502 rows x 5 columns]

# %%
ranged_items
# Out:
#                                               Item name  \
# 59    Fashion 2024 Mens Casual High-Top Shoes Runnin...
# 80      Kojic Acid Soap Body Skin Lightening Soap- 3pcs
# 83    Crease Guard Shoe Protector Sneakers Toe Caps ...
# 94    Fashion Beautiful Girls Back To School Shoes L...
# 95                    1Pcs Brown Curtain WITHOUT Sheers
# ...                                                 ...
# 1675  Always Stainless Steel Double Wall Insulated V...
# 1677  Always Unbreakable Vacuum Thermos Flask IN Sta...
# 1680             Waterproof Matress Protector And Cover
# 1681                 Kamisafe Emergency Backup LED Lamp
# 1683  Fashion 3PCs Cutest Ben 10 Pure Cotton Boys Bo...
#
#               Current price              Old price  Discount  \
# 59                KSh 1,860  KSh 2,695 - KSh 3,576      48.0
# 80        KSh 320 - KSh 923    KSh 320 - KSh 1,200      46.0
# 83        KSh 454 - KSh 499                KSh 789      42.0
# 94    KSh 1,020 - KSh 1,200  KSh 1,900 - KSh 2,500      56.0
# 95      KSh 990 - KSh 2,560  KSh 1,000 - KSh 2,900      12.0
# ...                     ...                    ...       ...
# 1675  KSh 1,889 - KSh 2,398  KSh 2,500 - KSh 3,800      37.0
# 1677  KSh 1,770 - KSh 2,350  KSh 2,300 - KSh 4,000      43.0
# 1680  KSh 2,275 - KSh 2,650  KSh 4,000 - KSh 5,200      50.0
# 1681  KSh 1,399 - KSh 2,965  KSh 1,700 - KSh 3,500      43.0
# 1683      KSh 499 - KSh 800                KSh 800      38.0
#
#                                                    Link
# 59    /fashion-2024-mens-casual-high-top-shoes-runni...
# 80    /kojie-san-skin-lightening-soap-original-3pcs-...
# 83    /generic-crease-guard-shoe-protector-sneakers-...
# 94    /fashion-beautiful-girls-back-to-school-shoes-...
# 95    /generic-1pcs-brown-curtain-without-sheers-152...
# ...                                                 ...
# 1675  /stainless-steel-double-wall-insulated-vacuum-...
# 1677  /always-unbreakable-vacuum-thermos-flask-in-st...
# 1680  /generic-waterproof-matress-protector-and-cove...
# 1681  /kamisafe-emergency-backup-led-lamp-29653629.html
# 1683  /fashion-3pcs-cutest-ben-10-pure-cotton-boys-b...
#
# [203 rows x 5 columns]

# %%
split_values = ranged_items['Current price'].str.split('-', expand=True)
ranged_items.loc[:, 'price_start_value'] = split_values[0].str.strip()
ranged_items.loc[:, 'price_end_value'] = split_values[1].str.strip()
ranged_items['price_end_value'].fillna(ranged_items['price_start_value'], inplace=True)

ranged_items
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_62492\4128325385.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ranged_items['price_end_value'].fillna(ranged_items['price_start_value'], inplace=True)
#                                               Item name  \
# 59    Fashion 2024 Mens Casual High-Top Shoes Runnin...
# 80      Kojic Acid Soap Body Skin Lightening Soap- 3pcs
# 83    Crease Guard Shoe Protector Sneakers Toe Caps ...
# 94    Fashion Beautiful Girls Back To School Shoes L...
# 95                    1Pcs Brown Curtain WITHOUT Sheers
# ...                                                 ...
# 1675  Always Stainless Steel Double Wall Insulated V...
# 1677  Always Unbreakable Vacuum Thermos Flask IN Sta...
# 1680             Waterproof Matress Protector And Cover
# 1681                 Kamisafe Emergency Backup LED Lamp
# 1683  Fashion 3PCs Cutest Ben 10 Pure Cotton Boys Bo...
#
#               Current price              Old price  Discount  \
# 59                KSh 1,860  KSh 2,695 - KSh 3,576      48.0
# 80        KSh 320 - KSh 923    KSh 320 - KSh 1,200      46.0
# 83        KSh 454 - KSh 499                KSh 789      42.0
# 94    KSh 1,020 - KSh 1,200  KSh 1,900 - KSh 2,500      56.0
# 95      KSh 990 - KSh 2,560  KSh 1,000 - KSh 2,900      12.0
# ...                     ...                    ...       ...
# 1675  KSh 1,889 - KSh 2,398  KSh 2,500 - KSh 3,800      37.0
# 1677  KSh 1,770 - KSh 2,350  KSh 2,300 - KSh 4,000      43.0
# 1680  KSh 2,275 - KSh 2,650  KSh 4,000 - KSh 5,200      50.0
# 1681  KSh 1,399 - KSh 2,965  KSh 1,700 - KSh 3,500      43.0
# 1683      KSh 499 - KSh 800                KSh 800      38.0
#
#                                                    Link price_start_value  \
# 59    /fashion-2024-mens-casual-high-top-shoes-runni...         KSh 1,860
# 80    /kojie-san-skin-lightening-soap-original-3pcs-...           KSh 320
# 83    /generic-crease-guard-shoe-protector-sneakers-...           KSh 454
# 94    /fashion-beautiful-girls-back-to-school-shoes-...         KSh 1,020
# 95    /generic-1pcs-brown-curtain-without-sheers-152...           KSh 990
# ...                                                 ...               ...
# 1675  /stainless-steel-double-wall-insulated-vacuum-...         KSh 1,889
# 1677  /always-unbreakable-vacuum-thermos-flask-in-st...         KSh 1,770
# 1680  /generic-waterproof-matress-protector-and-cove...         KSh 2,275
# 1681  /kamisafe-emergency-backup-led-lamp-29653629.html         KSh 1,399
# 1683  /fashion-3pcs-cutest-ben-10-pure-cotton-boys-b...           KSh 499
#
#      price_end_value
# 59         KSh 1,860
# 80           KSh 923
# 83           KSh 499
# 94         KSh 1,200
# 95         KSh 2,560
# ...              ...
# 1675       KSh 2,398
# 1677       KSh 2,350
# 1680       KSh 2,650
# 1681       KSh 2,965
# 1683         KSh 800
#
# [203 rows x 7 columns]

# %%
split_values = ranged_items['Old price'].str.split('-', expand=True)
ranged_items.loc[:, 'old_price_start_value'] = split_values[0].str.strip()
ranged_items.loc[:, 'old_price_end_value'] = split_values[1].str.strip()
ranged_items['old_price_end_value'].fillna(ranged_items['old_price_start_value'], inplace=True)

ranged_items
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_62492\1624745967.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ranged_items['old_price_end_value'].fillna(ranged_items['old_price_start_value'], inplace=True)
#                                               Item name  \
# 59    Fashion 2024 Mens Casual High-Top Shoes Runnin...
# 80      Kojic Acid Soap Body Skin Lightening Soap- 3pcs
# 83    Crease Guard Shoe Protector Sneakers Toe Caps ...
# 94    Fashion Beautiful Girls Back To School Shoes L...
# 95                    1Pcs Brown Curtain WITHOUT Sheers
# ...                                                 ...
# 1675  Always Stainless Steel Double Wall Insulated V...
# 1677  Always Unbreakable Vacuum Thermos Flask IN Sta...
# 1680             Waterproof Matress Protector And Cover
# 1681                 Kamisafe Emergency Backup LED Lamp
# 1683  Fashion 3PCs Cutest Ben 10 Pure Cotton Boys Bo...
#
#               Current price              Old price  Discount  \
# 59                KSh 1,860  KSh 2,695 - KSh 3,576      48.0
# 80        KSh 320 - KSh 923    KSh 320 - KSh 1,200      46.0
# 83        KSh 454 - KSh 499                KSh 789      42.0
# 94    KSh 1,020 - KSh 1,200  KSh 1,900 - KSh 2,500      56.0
# 95      KSh 990 - KSh 2,560  KSh 1,000 - KSh 2,900      12.0
# ...                     ...                    ...       ...
# 1675  KSh 1,889 - KSh 2,398  KSh 2,500 - KSh 3,800      37.0
# 1677  KSh 1,770 - KSh 2,350  KSh 2,300 - KSh 4,000      43.0
# 1680  KSh 2,275 - KSh 2,650  KSh 4,000 - KSh 5,200      50.0
# 1681  KSh 1,399 - KSh 2,965  KSh 1,700 - KSh 3,500      43.0
# 1683      KSh 499 - KSh 800                KSh 800      38.0
#
#                                                    Link price_start_value  \
# 59    /fashion-2024-mens-casual-high-top-shoes-runni...         KSh 1,860
# 80    /kojie-san-skin-lightening-soap-original-3pcs-...           KSh 320
# 83    /generic-crease-guard-shoe-protector-sneakers-...           KSh 454
# 94    /fashion-beautiful-girls-back-to-school-shoes-...         KSh 1,020
# 95    /generic-1pcs-brown-curtain-without-sheers-152...           KSh 990
# ...                                                 ...               ...
# 1675  /stainless-steel-double-wall-insulated-vacuum-...         KSh 1,889
# 1677  /always-unbreakable-vacuum-thermos-flask-in-st...         KSh 1,770
# 1680  /generic-waterproof-matress-protector-and-cove...         KSh 2,275
# 1681  /kamisafe-emergency-backup-led-lamp-29653629.html         KSh 1,399
# 1683  /fashion-3pcs-cutest-ben-10-pure-cotton-boys-b...           KSh 499
#
#      price_end_value old_price_start_value old_price_end_value
# 59         KSh 1,860             KSh 2,695           KSh 3,576
# 80           KSh 923               KSh 320           KSh 1,200
# 83           KSh 499               KSh 789             KSh 789
# 94         KSh 1,200             KSh 1,900           KSh 2,500
# 95         KSh 2,560             KSh 1,000           KSh 2,900
# ...              ...                   ...                 ...
# 1675       KSh 2,398             KSh 2,500           KSh 3,800
# 1677       KSh 2,350             KSh 2,300           KSh 4,000
# 1680       KSh 2,650             KSh 4,000           KSh 5,200
# 1681       KSh 2,965             KSh 1,700           KSh 3,500
# 1683         KSh 800               KSh 800             KSh 800
#
# [203 rows x 9 columns]

# %%
ranged_items.drop(['Current price', 'Old price'], axis = 1, inplace=True)
ranged_items
# Out:
#                                               Item name  Discount  \
# 59    Fashion 2024 Mens Casual High-Top Shoes Runnin...      48.0
# 80      Kojic Acid Soap Body Skin Lightening Soap- 3pcs      46.0
# 83    Crease Guard Shoe Protector Sneakers Toe Caps ...      42.0
# 94    Fashion Beautiful Girls Back To School Shoes L...      56.0
# 95                    1Pcs Brown Curtain WITHOUT Sheers      12.0
# ...                                                 ...       ...
# 1675  Always Stainless Steel Double Wall Insulated V...      37.0
# 1677  Always Unbreakable Vacuum Thermos Flask IN Sta...      43.0
# 1680             Waterproof Matress Protector And Cover      50.0
# 1681                 Kamisafe Emergency Backup LED Lamp      43.0
# 1683  Fashion 3PCs Cutest Ben 10 Pure Cotton Boys Bo...      38.0
#
#                                                    Link price_start_value  \
# 59    /fashion-2024-mens-casual-high-top-shoes-runni...         KSh 1,860
# 80    /kojie-san-skin-lightening-soap-original-3pcs-...           KSh 320
# 83    /generic-crease-guard-shoe-protector-sneakers-...           KSh 454
# 94    /fashion-beautiful-girls-back-to-school-shoes-...         KSh 1,020
# 95    /generic-1pcs-brown-curtain-without-sheers-152...           KSh 990
# ...                                                 ...               ...
# 1675  /stainless-steel-double-wall-insulated-vacuum-...         KSh 1,889
# 1677  /always-unbreakable-vacuum-thermos-flask-in-st...         KSh 1,770
# 1680  /generic-waterproof-matress-protector-and-cove...         KSh 2,275
# 1681  /kamisafe-emergency-backup-led-lamp-29653629.html         KSh 1,399
# 1683  /fashion-3pcs-cutest-ben-10-pure-cotton-boys-b...           KSh 499
#
#      price_end_value old_price_start_value old_price_end_value
# 59         KSh 1,860             KSh 2,695           KSh 3,576
# 80           KSh 923               KSh 320           KSh 1,200
# 83           KSh 499               KSh 789             KSh 789
# 94         KSh 1,200             KSh 1,900           KSh 2,500
# 95         KSh 2,560             KSh 1,000           KSh 2,900
# ...              ...                   ...                 ...
# 1675       KSh 2,398             KSh 2,500           KSh 3,800
# 1677       KSh 2,350             KSh 2,300           KSh 4,000
# 1680       KSh 2,650             KSh 4,000           KSh 5,200
# 1681       KSh 2,965             KSh 1,700           KSh 3,500
# 1683         KSh 800               KSh 800             KSh 800
#
# [203 rows x 7 columns]

# %%
# removing KSh string
columns_to_change = ['price_start_value','price_end_value','old_price_start_value','old_price_end_value']
ranged_items[columns_to_change] = ranged_items[columns_to_change].replace('KSh', '', regex=True)
ranged_items.head(5)
# Out:
#                                             Item name  Discount  \
# 59  Fashion 2024 Mens Casual High-Top Shoes Runnin...      48.0
# 80    Kojic Acid Soap Body Skin Lightening Soap- 3pcs      46.0
# 83  Crease Guard Shoe Protector Sneakers Toe Caps ...      42.0
# 94  Fashion Beautiful Girls Back To School Shoes L...      56.0
# 95                  1Pcs Brown Curtain WITHOUT Sheers      12.0
#
#                                                  Link price_start_value  \
# 59  /fashion-2024-mens-casual-high-top-shoes-runni...             1,860
# 80  /kojie-san-skin-lightening-soap-original-3pcs-...               320
# 83  /generic-crease-guard-shoe-protector-sneakers-...               454
# 94  /fashion-beautiful-girls-back-to-school-shoes-...             1,020
# 95  /generic-1pcs-brown-curtain-without-sheers-152...               990
#
#    price_end_value old_price_start_value old_price_end_value
# 59           1,860                 2,695               3,576
# 80             923                   320               1,200
# 83             499                   789                 789
# 94           1,200                 1,900               2,500
# 95           2,560                 1,000               2,900

# %%
# removing comma
columns_to_change = ['price_start_value','price_end_value','old_price_start_value','old_price_end_value']
ranged_items[columns_to_change] = ranged_items[columns_to_change].replace(',', '', regex=True)
ranged_items.head(5)
# Out:
#                                             Item name  Discount  \
# 59  Fashion 2024 Mens Casual High-Top Shoes Runnin...      48.0
# 80    Kojic Acid Soap Body Skin Lightening Soap- 3pcs      46.0
# 83  Crease Guard Shoe Protector Sneakers Toe Caps ...      42.0
# 94  Fashion Beautiful Girls Back To School Shoes L...      56.0
# 95                  1Pcs Brown Curtain WITHOUT Sheers      12.0
#
#                                                  Link price_start_value  \
# 59  /fashion-2024-mens-casual-high-top-shoes-runni...              1860
# 80  /kojie-san-skin-lightening-soap-original-3pcs-...               320
# 83  /generic-crease-guard-shoe-protector-sneakers-...               454
# 94  /fashion-beautiful-girls-back-to-school-shoes-...              1020
# 95  /generic-1pcs-brown-curtain-without-sheers-152...               990
#
#    price_end_value old_price_start_value old_price_end_value
# 59            1860                  2695                3576
# 80             923                   320                1200
# 83             499                   789                 789
# 94            1200                  1900                2500
# 95            2560                  1000                2900

# %%
# converting the column to float
columns_to_change = ['price_start_value','price_end_value','old_price_start_value','old_price_end_value']
ranged_items[columns_to_change] = ranged_items[columns_to_change].astype(float)
ranged_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 203 entries, 59 to 1683
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item name              203 non-null    object
#  1   Discount               203 non-null    float64
#  2   Link                   203 non-null    object
#  3   price_start_value      203 non-null    float64
#  4   price_end_value        203 non-null    float64
#  5   old_price_start_value  203 non-null    float64
#  6   old_price_end_value    203 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 12.7+ KB

# %%
ranged_items['current_price'] = (ranged_items['price_start_value'] + ranged_items['price_end_value'])/2
ranged_items['old_price'] = (ranged_items['old_price_start_value'] + ranged_items['old_price_end_value'])/2

ranged_items
# Out:
#                                               Item name  Discount  \
# 59    Fashion 2024 Mens Casual High-Top Shoes Runnin...      48.0
# 80      Kojic Acid Soap Body Skin Lightening Soap- 3pcs      46.0
# 83    Crease Guard Shoe Protector Sneakers Toe Caps ...      42.0
# 94    Fashion Beautiful Girls Back To School Shoes L...      56.0
# 95                    1Pcs Brown Curtain WITHOUT Sheers      12.0
# ...                                                 ...       ...
# 1675  Always Stainless Steel Double Wall Insulated V...      37.0
# 1677  Always Unbreakable Vacuum Thermos Flask IN Sta...      43.0
# 1680             Waterproof Matress Protector And Cover      50.0
# 1681                 Kamisafe Emergency Backup LED Lamp      43.0
# 1683  Fashion 3PCs Cutest Ben 10 Pure Cotton Boys Bo...      38.0
#
#                                                    Link  price_start_value  \
# 59    /fashion-2024-mens-casual-high-top-shoes-runni...             1860.0
# 80    /kojie-san-skin-lightening-soap-original-3pcs-...              320.0
# 83    /generic-crease-guard-shoe-protector-sneakers-...              454.0
# 94    /fashion-beautiful-girls-back-to-school-shoes-...             1020.0
# 95    /generic-1pcs-brown-curtain-without-sheers-152...              990.0
# ...                                                 ...                ...
# 1675  /stainless-steel-double-wall-insulated-vacuum-...             1889.0
# 1677  /always-unbreakable-vacuum-thermos-flask-in-st...             1770.0
# 1680  /generic-waterproof-matress-protector-and-cove...             2275.0
# 1681  /kamisafe-emergency-backup-led-lamp-29653629.html             1399.0
# 1683  /fashion-3pcs-cutest-ben-10-pure-cotton-boys-b...              499.0
#
#       price_end_value  old_price_start_value  old_price_end_value  \
# 59             1860.0                 2695.0               3576.0
# 80              923.0                  320.0               1200.0
# 83              499.0                  789.0                789.0
# 94             1200.0                 1900.0               2500.0
# 95             2560.0                 1000.0               2900.0
# ...               ...                    ...                  ...
# 1675           2398.0                 2500.0               3800.0
# 1677           2350.0                 2300.0               4000.0
# 1680           2650.0                 4000.0               5200.0
# 1681           2965.0                 1700.0               3500.0
# 1683            800.0                  800.0                800.0
#
#       current_price  old_price
# 59           1860.0     3135.5
# 80            621.5      760.0
# 83            476.5      789.0
# 94           1110.0     2200.0
# 95           1775.0     1950.0
# ...             ...        ...
# 1675         2143.5     3150.0
# 1677         2060.0     3150.0
# 1680         2462.5     4600.0
# 1681         2182.0     2600.0
# 1683          649.5      800.0
#
# [203 rows x 9 columns]

# %%
ranged_items.head()
# Out:
#                                             Item name  Discount  \
# 59  Fashion 2024 Mens Casual High-Top Shoes Runnin...      48.0
# 80    Kojic Acid Soap Body Skin Lightening Soap- 3pcs      46.0
# 83  Crease Guard Shoe Protector Sneakers Toe Caps ...      42.0
# 94  Fashion Beautiful Girls Back To School Shoes L...      56.0
# 95                  1Pcs Brown Curtain WITHOUT Sheers      12.0
#
#                                                  Link  price_start_value  \
# 59  /fashion-2024-mens-casual-high-top-shoes-runni...             1860.0
# 80  /kojie-san-skin-lightening-soap-original-3pcs-...              320.0
# 83  /generic-crease-guard-shoe-protector-sneakers-...              454.0
# 94  /fashion-beautiful-girls-back-to-school-shoes-...             1020.0
# 95  /generic-1pcs-brown-curtain-without-sheers-152...              990.0
#
#     price_end_value  old_price_start_value  old_price_end_value  \
# 59           1860.0                 2695.0               3576.0
# 80            923.0                  320.0               1200.0
# 83            499.0                  789.0                789.0
# 94           1200.0                 1900.0               2500.0
# 95           2560.0                 1000.0               2900.0
#
#     current_price  old_price
# 59         1860.0     3135.5
# 80          621.5      760.0
# 83          476.5      789.0
# 94         1110.0     2200.0
# 95         1775.0     1950.0

# %%
ranged_items.drop(columns = ['price_start_value','price_end_value','old_price_start_value', 'old_price_end_value'], inplace=True)
ranged_items.head()
# Out:
#                                             Item name  Discount  \
# 59  Fashion 2024 Mens Casual High-Top Shoes Runnin...      48.0
# 80    Kojic Acid Soap Body Skin Lightening Soap- 3pcs      46.0
# 83  Crease Guard Shoe Protector Sneakers Toe Caps ...      42.0
# 94  Fashion Beautiful Girls Back To School Shoes L...      56.0
# 95                  1Pcs Brown Curtain WITHOUT Sheers      12.0
#
#                                                  Link  current_price  \
# 59  /fashion-2024-mens-casual-high-top-shoes-runni...         1860.0
# 80  /kojie-san-skin-lightening-soap-original-3pcs-...          621.5
# 83  /generic-crease-guard-shoe-protector-sneakers-...          476.5
# 94  /fashion-beautiful-girls-back-to-school-shoes-...         1110.0
# 95  /generic-1pcs-brown-curtain-without-sheers-152...         1775.0
#
#     old_price
# 59     3135.5
# 80      760.0
# 83      789.0
# 94     2200.0
# 95     1950.0

# %%
ranged_items = ranged_items[['Item name','current_price','old_price','Discount','Link']]
ranged_items.rename(columns={'current_price':'Current price','old_price':'Old price'}, inplace=True)
ranged_items.head()
# Out:
#                                             Item name  Current price  \
# 59  Fashion 2024 Mens Casual High-Top Shoes Runnin...         1860.0
# 80    Kojic Acid Soap Body Skin Lightening Soap- 3pcs          621.5
# 83  Crease Guard Shoe Protector Sneakers Toe Caps ...          476.5
# 94  Fashion Beautiful Girls Back To School Shoes L...         1110.0
# 95                  1Pcs Brown Curtain WITHOUT Sheers         1775.0
#
#     Old price  Discount                                               Link
# 59     3135.5      48.0  /fashion-2024-mens-casual-high-top-shoes-runni...
# 80      760.0      46.0  /kojie-san-skin-lightening-soap-original-3pcs-...
# 83      789.0      42.0  /generic-crease-guard-shoe-protector-sneakers-...
# 94     2200.0      56.0  /fashion-beautiful-girls-back-to-school-shoes-...
# 95     1950.0      12.0  /generic-1pcs-brown-curtain-without-sheers-152...

# %%
new_product_data.head()
# Out:
#                                            Item name Current price  Old price  \
# 0  NIVEA Perfect & Radiant Even Tone Day And Nigh...       KSh 999  KSh 1,560
# 1  NIVEA Radiant & Beauty Advanced Care Lotion Fo...       KSh 949  KSh 1,460
# 2  NIVEA Nourishing Cocoa Body Lotion With Cocoa ...     KSh 1,174  KSh 1,302
# 3  NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...       KSh 728  KSh 1,040
# 4  NIVEA MEN Deep Antibacterial Anti-Perspirant R...       KSh 728  KSh 1,040
#
#    Discount                                               Link
# 0      36.0  /nivea-perfect-radiant-even-tone-day-and-night...
# 1      35.0  /nivea-radiant-beauty-advanced-care-lotion-for...
# 2      10.0  /nivea-nourishing-cocoa-body-lotion-with-cocoa...
# 3      30.0  /nivea-pearl-beauty-anti-perspirant-rollon-48h...
# 4      30.0  /nivea-men-deep-antibacterial-anti-perspirant-...

# %%
columns = ['Current price', 'Old price']
new_product_data[columns] = new_product_data[columns].replace('KSh', '', regex=True)
new_product_data[columns] = new_product_data[columns].replace(',', '',regex=True)
new_product_data.head()
# Out:
#                                            Item name Current price Old price  \
# 0  NIVEA Perfect & Radiant Even Tone Day And Nigh...           999      1560
# 1  NIVEA Radiant & Beauty Advanced Care Lotion Fo...           949      1460
# 2  NIVEA Nourishing Cocoa Body Lotion With Cocoa ...          1174      1302
# 3  NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...           728      1040
# 4  NIVEA MEN Deep Antibacterial Anti-Perspirant R...           728      1040
#
#    Discount                                               Link
# 0      36.0  /nivea-perfect-radiant-even-tone-day-and-night...
# 1      35.0  /nivea-radiant-beauty-advanced-care-lotion-for...
# 2      10.0  /nivea-nourishing-cocoa-body-lotion-with-cocoa...
# 3      30.0  /nivea-pearl-beauty-anti-perspirant-rollon-48h...
# 4      30.0  /nivea-men-deep-antibacterial-anti-perspirant-...

# %%
new_product_data[columns] = new_product_data[columns].astype(float)
new_product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1502 entries, 0 to 1704
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1502 non-null   object
#  1   Current price  1502 non-null   float64
#  2   Old price      1502 non-null   float64
#  3   Discount       1502 non-null   float64
#  4   Link           1502 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 70.4+ KB

# %%
products = pd.concat([new_product_data,ranged_items], axis=0)
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1705 entries, 0 to 1683
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1705 non-null   object
#  1   Current price  1705 non-null   float64
#  2   Old price      1705 non-null   float64
#  3   Discount       1705 non-null   float64
#  4   Link           1705 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 79.9+ KB

# %% [markdown]
# ## Exploratory Data Analysis(EDA)

# %%
products.head(10)
# Out:
#                                            Item name  Current price  \
# 0  NIVEA Perfect & Radiant Even Tone Day And Nigh...          999.0
# 1  NIVEA Radiant & Beauty Advanced Care Lotion Fo...          949.0
# 2  NIVEA Nourishing Cocoa Body Lotion With Cocoa ...         1174.0
# 3  NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...          728.0
# 4  NIVEA MEN Deep Antibacterial Anti-Perspirant R...          728.0
# 5  NIVEA Pearl & Beauty Black Pearl Fine Fragranc...          728.0
# 6  NIVEA Perfect & Radiant Luminous630 Anti Dark ...         3647.0
# 7  NIVEA Perfect & Radiant Even Tone Day Cream SP...          585.0
# 8  NIVEA Q10 Power Anti-Wrinkle Day Cream 50ml & ...         2496.0
# 9  Epson EcoTank L3250 A4 WIRELESS Printer (All-i...        33999.0
#
#    Old price  Discount                                               Link
# 0     1560.0      36.0  /nivea-perfect-radiant-even-tone-day-and-night...
# 1     1460.0      35.0  /nivea-radiant-beauty-advanced-care-lotion-for...
# 2     1302.0      10.0  /nivea-nourishing-cocoa-body-lotion-with-cocoa...
# 3     1040.0      30.0  /nivea-pearl-beauty-anti-perspirant-rollon-48h...
# 4     1040.0      30.0  /nivea-men-deep-antibacterial-anti-perspirant-...
# 5     1040.0      30.0  /nivea-pearl-beauty-black-pearl-fine-fragrance...
# 6     5610.0      35.0  /nivea-perfect-radiant-luminous630-anti-dark-m...
# 7      780.0      25.0  /nivea-perfect-radiant-even-tone-day-cream-spf...
# 8     3840.0      35.0  /nivea-q10-power-anti-wrinkle-day-cream-50ml-n...
# 9    38000.0      11.0  /epson-ecotank-l3250-a4-wireless-printer-all-i...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1705 entries, 0 to 1683
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1705 non-null   object
#  1   Current price  1705 non-null   float64
#  2   Old price      1705 non-null   float64
#  3   Discount       1705 non-null   float64
#  4   Link           1705 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 79.9+ KB

# %%
# 10 most expensive products
products.sort_values(by = 'Current price', ascending=False).head(10)
# Out:
#                                               Item name  Current price  \
# 703   Tecno Phantom V Flip 5G, 256GB + 8GB RAM (Sing...        97999.0
# 429   Ecoflow Portable Power Station RIVER 2 Pro, 76...        84999.0
# 1097  Samsung Galaxy S21 Ultra 5G 6.8″ 128GB + 12GB ...        68900.0
# 1157  Samsung Galaxy S21 Ultra 5G 6.8″ 128GB + 12GB ...        68900.0
# 1340  Oppo Reno10 5G, 6.7", 8+256, 64MP, 3D Curved S...        56999.0
# 1258  Oppo Reno 10 5G, 6.7'', 8GB RAM + 256GB, 64MP+...        54399.0
# 214   Oppo Reno 10 5G, 6.7''l.. 8GB + 256GB, 64MP, (...        53500.0
# 1186  Samsung Galaxy S20 Ultra 6.9" 5G 128GB SmartPh...        52900.0
# 639   Vitron 55" Inch Smart-Android,Bluetooth TV,FRA...        47999.0
# 1514  Vitron 55" UHD Frameless 4K Android TV+FREE AC...        47990.0
#
#       Old price  Discount                                               Link
# 703     99999.0       2.0  /tecno-phantom-v-flip-5g-256gb-8gb-ram-single-...
# 429    106999.0      21.0  /ecoflow-portable-power-station-river-2-pro-76...
# 1097    78900.0      13.0  /galaxy-s21-ultra-5g-6.8-128gb-12gb-black-sams...
# 1157    78900.0      13.0  /galaxy-s21-ultra-5g-6.8-128gb-12gb-black-sams...
# 1340    57999.0       2.0  /oppo-reno10-5g-6.7-8256-64mp-3d-curved-screen...
# 1258    79999.0      32.0  /oppo-reno-10-5g-6.7-8gb-ram-256gb-64mp32gb8gb...
# 214     70000.0      24.0  /reno-10-5g-6.7l..-8gb-256gb-64mp-dual-sim-500...
# 1186    82900.0      36.0  /galaxy-s20-ultra-6.9-5g-128gb-smartphones-bla...
# 639     90000.0      47.0  /55-inch-smart-androidbluetooth-tvframelessult...
# 1514    55000.0      13.0  /vitron-55-uhd-frameless-4k-android-tvfree-acc...

# %%
# 10 cheapest products
products.sort_values(by = 'Current price', ascending=True).head(10)
# Out:
#                                               Item name  Current price  \
# 1422  Portable Mini OTG Adapter Type-C To USB Conver...           43.0
# 1103  2Pcs High Speed Male to Female Type-C to USB O...           51.0
# 1163  2Pcs High Speed Male to Female Type-C to USB O...           51.0
# 874   Type-C OTG Adapter Connector Fast Charging Alu...           62.0
# 1606  Fashion Vintage Turtle Charm Handmade Woven An...           75.0
# 921   Fashion Moon Shape Star Pendant Alloy Luxury C...           78.0
# 79    Fashion Women Faux Pearl Ear Studs Earrings We...           82.0
# 906   Fashion Women Faux Pearl Ear Studs Earrings We...           82.0
# 350   Fashion Love Heart Pendant Chain Necklace Wome...           83.0
# 424   Silicone BBQ Sauce Oil Brush Handle Cake Butte...           90.0
#
#       Old price  Discount                                               Link
# 1422       86.0      50.0  /generic-portable-mini-otg-adapter-type-c-to-u...
# 1103      102.0      50.0  /2pcs-high-speed-male-to-female-type-c-to-usb-...
# 1163      102.0      50.0  /2pcs-high-speed-male-to-female-type-c-to-usb-...
# 874       124.0      50.0  /generic-type-c-otg-adapter-connector-fast-cha...
# 1606      150.0      50.0  /fashion-vintage-turtle-charm-handmade-woven-a...
# 921       156.0      50.0  /fashion-moon-shape-star-pendant-alloy-luxury-...
# 79        164.0      50.0  /fashion-women-faux-pearl-ear-studs-earrings-w...
# 906       164.0      50.0  /fashion-women-faux-pearl-ear-studs-earrings-w...
# 350       165.0      50.0  /fashion-love-heart-pendant-chain-necklace-wom...
# 424       180.0      50.0  /generic-silicone-bbq-sauce-oil-brush-handle-c...

# %%
# 10 prices with the highest discount
products.sort_values(by = 'Discount', ascending=False).head(10)
# Out:
#                                               Item name  Current price  \
# 232   Winner Transfer Laser Light 5 Sheets Transfer ...           99.0
# 1502  Fashion Back To School Shoes -Quality Genuine ...          939.0
# 1550                  FreshLook Beauty Eye Contact Lens          949.0
# 372   Fashion Men Glossy Casual Brogue Official Leat...         2540.0
# 94    Fashion Beautiful Girls Back To School Shoes L...         1110.0
# 1510  L.A. Girl High Definition Concealer Pro Concea...          209.0
# 461                 Kids Fleece Blankets/Throw Blankets          699.0
# 653                  Oraimo Trimmer With 4 Guided Combs         1650.0
# 1166     Safety Jogger Boots - Oil, H20, & Pierce Proof         2799.0
# 1106     Safety Jogger Boots - Oil, H20, & Pierce Proof         2799.0
#
#       Old price  Discount                                               Link
# 232       468.0      79.0  /winner-transfer-laser-light-5-sheets-transfer...
# 1502     1825.0      70.0  /back-to-school-shoes-quality-genuine-leather-...
# 1550     1500.0      60.0  /beauty-eye-contact-lens-freshlook-mpg420487.html
# 372      5999.0      58.0  /fashion-men-glossy-casual-brogue-official-lea...
# 94       2200.0      56.0  /fashion-beautiful-girls-back-to-school-shoes-...
# 1510      450.0      54.0  /l.a.-girl-high-definition-concealer-pro-conce...
# 461      1500.0      53.0  /generic-kids-fleece-blanketsthrow-blankets-15...
# 653      3499.0      53.0  /oraimo-trimmer-with-4-guided-combs-71964194.html
# 1166     6000.0      53.0  /generic-safety-jogger-boots-oil-h20-pierce-pr...
# 1106     6000.0      53.0  /generic-safety-jogger-boots-oil-h20-pierce-pr...
