# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
product_data = pd.read_csv('jumia_products_raw.csv')
product_data.head(10)
# Out:
#                                            Item name Current price  \
# 0  AILYONS FK-0301 Stainless Steel 1.8L Electric ...       KSh 599
# 1  Vitron HTC4388FS - 43" Smart  Android Frameles...    KSh 19,499
# 2  NIVEA Radiant & Beauty Advanced Care Lotion Fo...     KSh 1,022
# 3  Vitron HTC3200S 32" Smart Frameless Android LE...    KSh 11,599
# 4    NIVEA UV Face Shine Control Cream SPF 50 - 50ml       KSh 849
# 5  NIVEA Perfect & Radiant Even Tone Day And Nigh...       KSh 849
# 6  NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...       KSh 692
# 7  RichRipple LED Display Bluetooth Headsets 9D S...       KSh 469
# 8                     Starlink Standard Actuated Kit    KSh 39,500
# 9  Garnier Even & Matte Vitamin  C Booster Serum ...     KSh 1,099
#
#      Old price Discount                                               Link
# 0      KSh 628       5%  /ailyons-fk-0301-stainless-steel-1.8l-electric...
# 1   KSh 28,599      32%  /vitron-htc4388fs-43-smart-android-frameless-t...
# 2    KSh 1,460      30%  /nivea-radiant-beauty-advanced-care-lotion-for...
# 3   KSh 18,069      36%  /vitron-htc3200s-32-smart-frameless-android-le...
# 4    KSh 1,300      35%  /nivea-uv-face-shine-control-cream-spf-50-50ml...
# 5    KSh 1,800      53%  /nivea-perfect-radiant-even-tone-day-and-night...
# 6    KSh 1,040      33%  /nivea-pearl-beauty-anti-perspirant-rollon-48h...
# 7      KSh 920      49%  /richripple-led-display-bluetooth-headsets-9d-...
# 8  KSh 100,000      61%     /starlink-standard-actuated-kit-190334730.html
# 9    KSh 1,750      37%  /garnier-even-matte-vitamin-c-booster-serum-30...

# %%
product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1886 entries, 0 to 1885
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1886 non-null   object
#  1   Current price  1886 non-null   object
#  2   Old price      1886 non-null   object
#  3   Discount       1886 non-null   object
#  4   Link           1886 non-null   object
# dtypes: object(5)
# memory usage: 73.8+ KB

# %% [markdown]
# ## Data cleaning

# %%
# changin discount column to float
def change_disc_col(df):
    df['Discount'] = df['Discount'].str.replace('%','')
    df['Discount'] = df['Discount'].astype(float)
    return df.info()

change_disc_col(product_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1886 entries, 0 to 1885
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1886 non-null   object
#  1   Current price  1886 non-null   object
#  2   Old price      1886 non-null   object
#  3   Discount       1886 non-null   float64
#  4   Link           1886 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 73.8+ KB

# %%
# filtering out prices that have a range
ranged_items = product_data[product_data['Current price'].str.contains('-') | product_data['Old price'].str.contains('-')].copy()
# removing the rows from the original dataset
new_product_data = product_data.drop(ranged_items.index)
new_product_data
# Out:
#                                               Item name Current price  \
# 0     AILYONS FK-0301 Stainless Steel 1.8L Electric ...       KSh 599
# 1     Vitron HTC4388FS - 43" Smart  Android Frameles...    KSh 19,499
# 2     NIVEA Radiant & Beauty Advanced Care Lotion Fo...     KSh 1,022
# 3     Vitron HTC3200S 32" Smart Frameless Android LE...    KSh 11,599
# 4       NIVEA UV Face Shine Control Cream SPF 50 - 50ml       KSh 849
# ...                                                 ...           ...
# 1881  Garnier Brightening Night Serum With 10% Pure ...     KSh 3,229
# 1882  500in1 Mini Classic Games Double Game Player G...     KSh 1,805
# 1883  New 2023 Super Bright 500W UFO Shape LED Solar...     KSh 9,000
# 1884  Flip Mobile Phone Double SIM Large Font Large ...     KSh 3,970
# 1885  New Slim Usb Rechargeable Cigar Cigarette Flam...       KSh 989
#
#        Old price  Discount                                               Link
# 0        KSh 628       5.0  /ailyons-fk-0301-stainless-steel-1.8l-electric...
# 1     KSh 28,599      32.0  /vitron-htc4388fs-43-smart-android-frameless-t...
# 2      KSh 1,460      30.0  /nivea-radiant-beauty-advanced-care-lotion-for...
# 3     KSh 18,069      36.0  /vitron-htc3200s-32-smart-frameless-android-le...
# 4      KSh 1,300      35.0  /nivea-uv-face-shine-control-cream-spf-50-50ml...
# ...          ...       ...                                                ...
# 1881   KSh 3,399       5.0  /garnier-brightening-night-serum-with-10-pure-...
# 1882   KSh 2,318      22.0  /generic-500in1-mini-classic-games-double-game...
# 1883  KSh 14,500      38.0  /generic-new-2023-super-bright-500w-ufo-shape-...
# 1884   KSh 5,700      30.0  /generic-flip-mobile-phone-double-sim-large-fo...
# 1885   KSh 1,885      48.0  /generic-new-slim-usb-rechargeable-cigar-cigar...
#
# [1721 rows x 5 columns]

# %%
ranged_items
# Out:
#                                               Item name  \
# 45    Fashion Men Shoes Sneakers Skateboarding Shoes...
# 78               Rugged Mommy Jeans Ladies Denim Jeans
# 79    Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...
# 82    Fashion Official Turkey Mens Longsleeve Shirt ...
# 90    Fashion Navy Blue Official Mens Longsleeve Shi...
# ...                                                 ...
# 1808             Fashion Sacha Buttercup Setting Powder
# 1836  Alcohol Is Coming Hip Flask 210 ML Stainless S...
# 1838                     Name Plate Small, Medium & Big
# 1855  Curtains Turquoise Blue 2Pcs 1.5M Each + FREE ...
# 1873  Femme Organics Sandalwood Turmeric Bridal Face...
#
#               Current price              Old price  Discount  \
# 45    KSh 1,059 - KSh 1,099  KSh 1,371 - KSh 1,913      43.0
# 78    KSh 1,389 - KSh 1,489  KSh 1,500 - KSh 1,600      13.0
# 79    KSh 1,089 - KSh 1,289              KSh 1,500      27.0
# 82      KSh 789 - KSh 1,189  KSh 1,500 - KSh 1,599      47.0
# 90        KSh 889 - KSh 929    KSh 949 - KSh 1,500      41.0
# ...                     ...                    ...       ...
# 1808      KSh 285 - KSh 500                KSh 500      43.0
# 1836  KSh 1,900 - KSh 2,470  KSh 2,000 - KSh 2,600       5.0
# 1838      KSh 760 - KSh 950    KSh 800 - KSh 1,000       5.0
# 1855  KSh 3,499 - KSh 4,499  KSh 4,700 - KSh 6,000      30.0
# 1873      KSh 280 - KSh 670    KSh 500 - KSh 1,400      52.0
#
#                                                    Link
# 45    /fashion-men-shoes-sneakers-skateboarding-shoe...
# 78    /generic-rugged-mommy-jeans-ladies-denim-jeans...
# 79    /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...
# 82    /official-turkey-mens-longsleeve-shirt-slim-fi...
# 90    /fashion-navy-blue-official-mens-longsleeve-sh...
# ...                                                 ...
# 1808  /sacha-buttercup-setting-powder-fashion-mpg126...
# 1836  /alcohol-is-coming-hip-flask-210-ml-stainless-...
# 1838  /generic-name-plate-small-medium-big-161811911...
# 1855  /generic-curtains-turquoise-blue-2pcs-1.5m-eac...
# 1873  /femme-organics-sandalwood-turmeric-bridal-fac...
#
# [165 rows x 5 columns]

# %%
split_values = ranged_items['Current price'].str.split('-', expand=True)
ranged_items.loc[:, 'price_start_value'] = split_values[0].str.strip()
ranged_items.loc[:, 'price_end_value'] = split_values[1].str.strip()
ranged_items['price_end_value'].fillna(ranged_items['price_start_value'], inplace=True)

ranged_items
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11068\4128325385.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ranged_items['price_end_value'].fillna(ranged_items['price_start_value'], inplace=True)
#                                               Item name  \
# 45    Fashion Men Shoes Sneakers Skateboarding Shoes...
# 78               Rugged Mommy Jeans Ladies Denim Jeans
# 79    Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...
# 82    Fashion Official Turkey Mens Longsleeve Shirt ...
# 90    Fashion Navy Blue Official Mens Longsleeve Shi...
# ...                                                 ...
# 1808             Fashion Sacha Buttercup Setting Powder
# 1836  Alcohol Is Coming Hip Flask 210 ML Stainless S...
# 1838                     Name Plate Small, Medium & Big
# 1855  Curtains Turquoise Blue 2Pcs 1.5M Each + FREE ...
# 1873  Femme Organics Sandalwood Turmeric Bridal Face...
#
#               Current price              Old price  Discount  \
# 45    KSh 1,059 - KSh 1,099  KSh 1,371 - KSh 1,913      43.0
# 78    KSh 1,389 - KSh 1,489  KSh 1,500 - KSh 1,600      13.0
# 79    KSh 1,089 - KSh 1,289              KSh 1,500      27.0
# 82      KSh 789 - KSh 1,189  KSh 1,500 - KSh 1,599      47.0
# 90        KSh 889 - KSh 929    KSh 949 - KSh 1,500      41.0
# ...                     ...                    ...       ...
# 1808      KSh 285 - KSh 500                KSh 500      43.0
# 1836  KSh 1,900 - KSh 2,470  KSh 2,000 - KSh 2,600       5.0
# 1838      KSh 760 - KSh 950    KSh 800 - KSh 1,000       5.0
# 1855  KSh 3,499 - KSh 4,499  KSh 4,700 - KSh 6,000      30.0
# 1873      KSh 280 - KSh 670    KSh 500 - KSh 1,400      52.0
#
#                                                    Link price_start_value  \
# 45    /fashion-men-shoes-sneakers-skateboarding-shoe...         KSh 1,059
# 78    /generic-rugged-mommy-jeans-ladies-denim-jeans...         KSh 1,389
# 79    /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...         KSh 1,089
# 82    /official-turkey-mens-longsleeve-shirt-slim-fi...           KSh 789
# 90    /fashion-navy-blue-official-mens-longsleeve-sh...           KSh 889
# ...                                                 ...               ...
# 1808  /sacha-buttercup-setting-powder-fashion-mpg126...           KSh 285
# 1836  /alcohol-is-coming-hip-flask-210-ml-stainless-...         KSh 1,900
# 1838  /generic-name-plate-small-medium-big-161811911...           KSh 760
# 1855  /generic-curtains-turquoise-blue-2pcs-1.5m-eac...         KSh 3,499
# 1873  /femme-organics-sandalwood-turmeric-bridal-fac...           KSh 280
#
#      price_end_value
# 45         KSh 1,099
# 78         KSh 1,489
# 79         KSh 1,289
# 82         KSh 1,189
# 90           KSh 929
# ...              ...
# 1808         KSh 500
# 1836       KSh 2,470
# 1838         KSh 950
# 1855       KSh 4,499
# 1873         KSh 670
#
# [165 rows x 7 columns]

# %%
split_values = ranged_items['Old price'].str.split('-', expand=True)
ranged_items.loc[:, 'old_price_start_value'] = split_values[0].str.strip()
ranged_items.loc[:, 'old_price_end_value'] = split_values[1].str.strip()
ranged_items['old_price_end_value'].fillna(ranged_items['old_price_start_value'], inplace=True)

ranged_items
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11068\1624745967.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ranged_items['old_price_end_value'].fillna(ranged_items['old_price_start_value'], inplace=True)
#                                               Item name  \
# 45    Fashion Men Shoes Sneakers Skateboarding Shoes...
# 78               Rugged Mommy Jeans Ladies Denim Jeans
# 79    Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...
# 82    Fashion Official Turkey Mens Longsleeve Shirt ...
# 90    Fashion Navy Blue Official Mens Longsleeve Shi...
# ...                                                 ...
# 1808             Fashion Sacha Buttercup Setting Powder
# 1836  Alcohol Is Coming Hip Flask 210 ML Stainless S...
# 1838                     Name Plate Small, Medium & Big
# 1855  Curtains Turquoise Blue 2Pcs 1.5M Each + FREE ...
# 1873  Femme Organics Sandalwood Turmeric Bridal Face...
#
#               Current price              Old price  Discount  \
# 45    KSh 1,059 - KSh 1,099  KSh 1,371 - KSh 1,913      43.0
# 78    KSh 1,389 - KSh 1,489  KSh 1,500 - KSh 1,600      13.0
# 79    KSh 1,089 - KSh 1,289              KSh 1,500      27.0
# 82      KSh 789 - KSh 1,189  KSh 1,500 - KSh 1,599      47.0
# 90        KSh 889 - KSh 929    KSh 949 - KSh 1,500      41.0
# ...                     ...                    ...       ...
# 1808      KSh 285 - KSh 500                KSh 500      43.0
# 1836  KSh 1,900 - KSh 2,470  KSh 2,000 - KSh 2,600       5.0
# 1838      KSh 760 - KSh 950    KSh 800 - KSh 1,000       5.0
# 1855  KSh 3,499 - KSh 4,499  KSh 4,700 - KSh 6,000      30.0
# 1873      KSh 280 - KSh 670    KSh 500 - KSh 1,400      52.0
#
#                                                    Link price_start_value  \
# 45    /fashion-men-shoes-sneakers-skateboarding-shoe...         KSh 1,059
# 78    /generic-rugged-mommy-jeans-ladies-denim-jeans...         KSh 1,389
# 79    /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...         KSh 1,089
# 82    /official-turkey-mens-longsleeve-shirt-slim-fi...           KSh 789
# 90    /fashion-navy-blue-official-mens-longsleeve-sh...           KSh 889
# ...                                                 ...               ...
# 1808  /sacha-buttercup-setting-powder-fashion-mpg126...           KSh 285
# 1836  /alcohol-is-coming-hip-flask-210-ml-stainless-...         KSh 1,900
# 1838  /generic-name-plate-small-medium-big-161811911...           KSh 760
# 1855  /generic-curtains-turquoise-blue-2pcs-1.5m-eac...         KSh 3,499
# 1873  /femme-organics-sandalwood-turmeric-bridal-fac...           KSh 280
#
#      price_end_value old_price_start_value old_price_end_value
# 45         KSh 1,099             KSh 1,371           KSh 1,913
# 78         KSh 1,489             KSh 1,500           KSh 1,600
# 79         KSh 1,289             KSh 1,500           KSh 1,500
# 82         KSh 1,189             KSh 1,500           KSh 1,599
# 90           KSh 929               KSh 949           KSh 1,500
# ...              ...                   ...                 ...
# 1808         KSh 500               KSh 500             KSh 500
# 1836       KSh 2,470             KSh 2,000           KSh 2,600
# 1838         KSh 950               KSh 800           KSh 1,000
# 1855       KSh 4,499             KSh 4,700           KSh 6,000
# 1873         KSh 670               KSh 500           KSh 1,400
#
# [165 rows x 9 columns]

# %%
ranged_items.drop(['Current price', 'Old price'], axis = 1, inplace=True)
ranged_items
# Out:
#                                               Item name  Discount  \
# 45    Fashion Men Shoes Sneakers Skateboarding Shoes...      43.0
# 78               Rugged Mommy Jeans Ladies Denim Jeans       13.0
# 79    Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...      27.0
# 82    Fashion Official Turkey Mens Longsleeve Shirt ...      47.0
# 90    Fashion Navy Blue Official Mens Longsleeve Shi...      41.0
# ...                                                 ...       ...
# 1808             Fashion Sacha Buttercup Setting Powder      43.0
# 1836  Alcohol Is Coming Hip Flask 210 ML Stainless S...       5.0
# 1838                     Name Plate Small, Medium & Big       5.0
# 1855  Curtains Turquoise Blue 2Pcs 1.5M Each + FREE ...      30.0
# 1873  Femme Organics Sandalwood Turmeric Bridal Face...      52.0
#
#                                                    Link price_start_value  \
# 45    /fashion-men-shoes-sneakers-skateboarding-shoe...         KSh 1,059
# 78    /generic-rugged-mommy-jeans-ladies-denim-jeans...         KSh 1,389
# 79    /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...         KSh 1,089
# 82    /official-turkey-mens-longsleeve-shirt-slim-fi...           KSh 789
# 90    /fashion-navy-blue-official-mens-longsleeve-sh...           KSh 889
# ...                                                 ...               ...
# 1808  /sacha-buttercup-setting-powder-fashion-mpg126...           KSh 285
# 1836  /alcohol-is-coming-hip-flask-210-ml-stainless-...         KSh 1,900
# 1838  /generic-name-plate-small-medium-big-161811911...           KSh 760
# 1855  /generic-curtains-turquoise-blue-2pcs-1.5m-eac...         KSh 3,499
# 1873  /femme-organics-sandalwood-turmeric-bridal-fac...           KSh 280
#
#      price_end_value old_price_start_value old_price_end_value
# 45         KSh 1,099             KSh 1,371           KSh 1,913
# 78         KSh 1,489             KSh 1,500           KSh 1,600
# 79         KSh 1,289             KSh 1,500           KSh 1,500
# 82         KSh 1,189             KSh 1,500           KSh 1,599
# 90           KSh 929               KSh 949           KSh 1,500
# ...              ...                   ...                 ...
# 1808         KSh 500               KSh 500             KSh 500
# 1836       KSh 2,470             KSh 2,000           KSh 2,600
# 1838         KSh 950               KSh 800           KSh 1,000
# 1855       KSh 4,499             KSh 4,700           KSh 6,000
# 1873         KSh 670               KSh 500           KSh 1,400
#
# [165 rows x 7 columns]

# %%
# removing KSh string
columns_to_change = ['price_start_value','price_end_value','old_price_start_value','old_price_end_value']
ranged_items[columns_to_change] = ranged_items[columns_to_change].replace('KSh', '', regex=True)
ranged_items.head(5)
# Out:
#                                             Item name  Discount  \
# 45  Fashion Men Shoes Sneakers Skateboarding Shoes...      43.0
# 78             Rugged Mommy Jeans Ladies Denim Jeans       13.0
# 79  Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...      27.0
# 82  Fashion Official Turkey Mens Longsleeve Shirt ...      47.0
# 90  Fashion Navy Blue Official Mens Longsleeve Shi...      41.0
#
#                                                  Link price_start_value  \
# 45  /fashion-men-shoes-sneakers-skateboarding-shoe...             1,059
# 78  /generic-rugged-mommy-jeans-ladies-denim-jeans...             1,389
# 79  /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...             1,089
# 82  /official-turkey-mens-longsleeve-shirt-slim-fi...               789
# 90  /fashion-navy-blue-official-mens-longsleeve-sh...               889
#
#    price_end_value old_price_start_value old_price_end_value
# 45           1,099                 1,371               1,913
# 78           1,489                 1,500               1,600
# 79           1,289                 1,500               1,500
# 82           1,189                 1,500               1,599
# 90             929                   949               1,500

# %%
# removing comma
columns_to_change = ['price_start_value','price_end_value','old_price_start_value','old_price_end_value']
ranged_items[columns_to_change] = ranged_items[columns_to_change].replace(',', '', regex=True)
ranged_items.head(5)
# Out:
#                                             Item name  Discount  \
# 45  Fashion Men Shoes Sneakers Skateboarding Shoes...      43.0
# 78             Rugged Mommy Jeans Ladies Denim Jeans       13.0
# 79  Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...      27.0
# 82  Fashion Official Turkey Mens Longsleeve Shirt ...      47.0
# 90  Fashion Navy Blue Official Mens Longsleeve Shi...      41.0
#
#                                                  Link price_start_value  \
# 45  /fashion-men-shoes-sneakers-skateboarding-shoe...              1059
# 78  /generic-rugged-mommy-jeans-ladies-denim-jeans...              1389
# 79  /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...              1089
# 82  /official-turkey-mens-longsleeve-shirt-slim-fi...               789
# 90  /fashion-navy-blue-official-mens-longsleeve-sh...               889
#
#    price_end_value old_price_start_value old_price_end_value
# 45            1099                  1371                1913
# 78            1489                  1500                1600
# 79            1289                  1500                1500
# 82            1189                  1500                1599
# 90             929                   949                1500

# %%
# converting the column to float
columns_to_change = ['price_start_value','price_end_value','old_price_start_value','old_price_end_value']
ranged_items[columns_to_change] = ranged_items[columns_to_change].astype(float)
ranged_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 45 to 1873
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item name              165 non-null    object
#  1   Discount               165 non-null    float64
#  2   Link                   165 non-null    object
#  3   price_start_value      165 non-null    float64
#  4   price_end_value        165 non-null    float64
#  5   old_price_start_value  165 non-null    float64
#  6   old_price_end_value    165 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 10.3+ KB

# %%
ranged_items['current_price'] = (ranged_items['price_start_value'] + ranged_items['price_end_value'])/2
ranged_items['old_price'] = (ranged_items['old_price_start_value'] + ranged_items['old_price_end_value'])/2

ranged_items
# Out:
#                                               Item name  Discount  \
# 45    Fashion Men Shoes Sneakers Skateboarding Shoes...      43.0
# 78               Rugged Mommy Jeans Ladies Denim Jeans       13.0
# 79    Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...      27.0
# 82    Fashion Official Turkey Mens Longsleeve Shirt ...      47.0
# 90    Fashion Navy Blue Official Mens Longsleeve Shi...      41.0
# ...                                                 ...       ...
# 1808             Fashion Sacha Buttercup Setting Powder      43.0
# 1836  Alcohol Is Coming Hip Flask 210 ML Stainless S...       5.0
# 1838                     Name Plate Small, Medium & Big       5.0
# 1855  Curtains Turquoise Blue 2Pcs 1.5M Each + FREE ...      30.0
# 1873  Femme Organics Sandalwood Turmeric Bridal Face...      52.0
#
#                                                    Link  price_start_value  \
# 45    /fashion-men-shoes-sneakers-skateboarding-shoe...             1059.0
# 78    /generic-rugged-mommy-jeans-ladies-denim-jeans...             1389.0
# 79    /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...             1089.0
# 82    /official-turkey-mens-longsleeve-shirt-slim-fi...              789.0
# 90    /fashion-navy-blue-official-mens-longsleeve-sh...              889.0
# ...                                                 ...                ...
# 1808  /sacha-buttercup-setting-powder-fashion-mpg126...              285.0
# 1836  /alcohol-is-coming-hip-flask-210-ml-stainless-...             1900.0
# 1838  /generic-name-plate-small-medium-big-161811911...              760.0
# 1855  /generic-curtains-turquoise-blue-2pcs-1.5m-eac...             3499.0
# 1873  /femme-organics-sandalwood-turmeric-bridal-fac...              280.0
#
#       price_end_value  old_price_start_value  old_price_end_value  \
# 45             1099.0                 1371.0               1913.0
# 78             1489.0                 1500.0               1600.0
# 79             1289.0                 1500.0               1500.0
# 82             1189.0                 1500.0               1599.0
# 90              929.0                  949.0               1500.0
# ...               ...                    ...                  ...
# 1808            500.0                  500.0                500.0
# 1836           2470.0                 2000.0               2600.0
# 1838            950.0                  800.0               1000.0
# 1855           4499.0                 4700.0               6000.0
# 1873            670.0                  500.0               1400.0
#
#       current_price  old_price
# 45           1079.0     1642.0
# 78           1439.0     1550.0
# 79           1189.0     1500.0
# 82            989.0     1549.5
# 90            909.0     1224.5
# ...             ...        ...
# 1808          392.5      500.0
# 1836         2185.0     2300.0
# 1838          855.0      900.0
# 1855         3999.0     5350.0
# 1873          475.0      950.0
#
# [165 rows x 9 columns]

# %%
ranged_items.head()
# Out:
#                                             Item name  Discount  \
# 45  Fashion Men Shoes Sneakers Skateboarding Shoes...      43.0
# 78             Rugged Mommy Jeans Ladies Denim Jeans       13.0
# 79  Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...      27.0
# 82  Fashion Official Turkey Mens Longsleeve Shirt ...      47.0
# 90  Fashion Navy Blue Official Mens Longsleeve Shi...      41.0
#
#                                                  Link  price_start_value  \
# 45  /fashion-men-shoes-sneakers-skateboarding-shoe...             1059.0
# 78  /generic-rugged-mommy-jeans-ladies-denim-jeans...             1389.0
# 79  /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...             1089.0
# 82  /official-turkey-mens-longsleeve-shirt-slim-fi...              789.0
# 90  /fashion-navy-blue-official-mens-longsleeve-sh...              889.0
#
#     price_end_value  old_price_start_value  old_price_end_value  \
# 45           1099.0                 1371.0               1913.0
# 78           1489.0                 1500.0               1600.0
# 79           1289.0                 1500.0               1500.0
# 82           1189.0                 1500.0               1599.0
# 90            929.0                  949.0               1500.0
#
#     current_price  old_price
# 45         1079.0     1642.0
# 78         1439.0     1550.0
# 79         1189.0     1500.0
# 82          989.0     1549.5
# 90          909.0     1224.5

# %%
ranged_items.drop(columns = ['price_start_value','price_end_value','old_price_start_value', 'old_price_end_value'], inplace=True)
ranged_items.head()
# Out:
#                                             Item name  Discount  \
# 45  Fashion Men Shoes Sneakers Skateboarding Shoes...      43.0
# 78             Rugged Mommy Jeans Ladies Denim Jeans       13.0
# 79  Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...      27.0
# 82  Fashion Official Turkey Mens Longsleeve Shirt ...      47.0
# 90  Fashion Navy Blue Official Mens Longsleeve Shi...      41.0
#
#                                                  Link  current_price  \
# 45  /fashion-men-shoes-sneakers-skateboarding-shoe...         1079.0
# 78  /generic-rugged-mommy-jeans-ladies-denim-jeans...         1439.0
# 79  /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...         1189.0
# 82  /official-turkey-mens-longsleeve-shirt-slim-fi...          989.0
# 90  /fashion-navy-blue-official-mens-longsleeve-sh...          909.0
#
#     old_price
# 45     1642.0
# 78     1550.0
# 79     1500.0
# 82     1549.5
# 90     1224.5

# %%
ranged_items = ranged_items[['Item name','current_price','old_price','Discount','Link']]
ranged_items.rename(columns={'current_price':'Current price','old_price':'Old price'}, inplace=True)
ranged_items.head()
# Out:
#                                             Item name  Current price  \
# 45  Fashion Men Shoes Sneakers Skateboarding Shoes...         1079.0
# 78             Rugged Mommy Jeans Ladies Denim Jeans          1439.0
# 79  Fashion 6PCs  Cutest Kids Comfy Pure Cotton Bo...         1189.0
# 82  Fashion Official Turkey Mens Longsleeve Shirt ...          989.0
# 90  Fashion Navy Blue Official Mens Longsleeve Shi...          909.0
#
#     Old price  Discount                                               Link
# 45     1642.0      43.0  /fashion-men-shoes-sneakers-skateboarding-shoe...
# 78     1550.0      13.0  /generic-rugged-mommy-jeans-ladies-denim-jeans...
# 79     1500.0      27.0  /fashion-6pcs-cutest-kids-comfy-pure-cotton-bo...
# 82     1549.5      47.0  /official-turkey-mens-longsleeve-shirt-slim-fi...
# 90     1224.5      41.0  /fashion-navy-blue-official-mens-longsleeve-sh...

# %%
new_product_data.head()
# Out:
#                                            Item name Current price  \
# 0  AILYONS FK-0301 Stainless Steel 1.8L Electric ...       KSh 599
# 1  Vitron HTC4388FS - 43" Smart  Android Frameles...    KSh 19,499
# 2  NIVEA Radiant & Beauty Advanced Care Lotion Fo...     KSh 1,022
# 3  Vitron HTC3200S 32" Smart Frameless Android LE...    KSh 11,599
# 4    NIVEA UV Face Shine Control Cream SPF 50 - 50ml       KSh 849
#
#     Old price  Discount                                               Link
# 0     KSh 628       5.0  /ailyons-fk-0301-stainless-steel-1.8l-electric...
# 1  KSh 28,599      32.0  /vitron-htc4388fs-43-smart-android-frameless-t...
# 2   KSh 1,460      30.0  /nivea-radiant-beauty-advanced-care-lotion-for...
# 3  KSh 18,069      36.0  /vitron-htc3200s-32-smart-frameless-android-le...
# 4   KSh 1,300      35.0  /nivea-uv-face-shine-control-cream-spf-50-50ml...

# %%
columns = ['Current price', 'Old price']
new_product_data[columns] = new_product_data[columns].replace('KSh', '', regex=True)
new_product_data[columns] = new_product_data[columns].replace(',', '',regex=True)
new_product_data.head()
# Out:
#                                            Item name Current price Old price  \
# 0  AILYONS FK-0301 Stainless Steel 1.8L Electric ...           599       628
# 1  Vitron HTC4388FS - 43" Smart  Android Frameles...         19499     28599
# 2  NIVEA Radiant & Beauty Advanced Care Lotion Fo...          1022      1460
# 3  Vitron HTC3200S 32" Smart Frameless Android LE...         11599     18069
# 4    NIVEA UV Face Shine Control Cream SPF 50 - 50ml           849      1300
#
#    Discount                                               Link
# 0       5.0  /ailyons-fk-0301-stainless-steel-1.8l-electric...
# 1      32.0  /vitron-htc4388fs-43-smart-android-frameless-t...
# 2      30.0  /nivea-radiant-beauty-advanced-care-lotion-for...
# 3      36.0  /vitron-htc3200s-32-smart-frameless-android-le...
# 4      35.0  /nivea-uv-face-shine-control-cream-spf-50-50ml...

# %%
new_product_data[columns] = new_product_data[columns].astype(float)
new_product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721 entries, 0 to 1885
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1721 non-null   object
#  1   Current price  1721 non-null   float64
#  2   Old price      1721 non-null   float64
#  3   Discount       1721 non-null   float64
#  4   Link           1721 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 80.7+ KB

# %%
products = pd.concat([new_product_data,ranged_items], axis=0)
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1886 entries, 0 to 1873
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1886 non-null   object
#  1   Current price  1886 non-null   float64
#  2   Old price      1886 non-null   float64
#  3   Discount       1886 non-null   float64
#  4   Link           1886 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 88.4+ KB

# %% [markdown]
# Saving the cleaned data as csv file

# %%
products.to_csv('jumia_products_clean.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis(EDA)

# %%
products.head(10)
# Out:
#                                            Item name  Current price  \
# 0  AILYONS FK-0301 Stainless Steel 1.8L Electric ...          599.0
# 1  Vitron HTC4388FS - 43" Smart  Android Frameles...        19499.0
# 2  NIVEA Radiant & Beauty Advanced Care Lotion Fo...         1022.0
# 3  Vitron HTC3200S 32" Smart Frameless Android LE...        11599.0
# 4    NIVEA UV Face Shine Control Cream SPF 50 - 50ml          849.0
# 5  NIVEA Perfect & Radiant Even Tone Day And Nigh...          849.0
# 6  NIVEA Pearl & Beauty Anti-Perspirant Rollon, 4...          692.0
# 7  RichRipple LED Display Bluetooth Headsets 9D S...          469.0
# 8                     Starlink Standard Actuated Kit        39500.0
# 9  Garnier Even & Matte Vitamin  C Booster Serum ...         1099.0
#
#    Old price  Discount                                               Link
# 0      628.0       5.0  /ailyons-fk-0301-stainless-steel-1.8l-electric...
# 1    28599.0      32.0  /vitron-htc4388fs-43-smart-android-frameless-t...
# 2     1460.0      30.0  /nivea-radiant-beauty-advanced-care-lotion-for...
# 3    18069.0      36.0  /vitron-htc3200s-32-smart-frameless-android-le...
# 4     1300.0      35.0  /nivea-uv-face-shine-control-cream-spf-50-50ml...
# 5     1800.0      53.0  /nivea-perfect-radiant-even-tone-day-and-night...
# 6     1040.0      33.0  /nivea-pearl-beauty-anti-perspirant-rollon-48h...
# 7      920.0      49.0  /richripple-led-display-bluetooth-headsets-9d-...
# 8   100000.0      61.0     /starlink-standard-actuated-kit-190334730.html
# 9     1750.0      37.0  /garnier-even-matte-vitamin-c-booster-serum-30...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1886 entries, 0 to 1873
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item name      1886 non-null   object
#  1   Current price  1886 non-null   float64
#  2   Old price      1886 non-null   float64
#  3   Discount       1886 non-null   float64
#  4   Link           1886 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 88.4+ KB

# %%
# 10 most expensive products
products.sort_values(by = 'Current price', ascending=False).head(10)
# Out:
#                                               Item name  Current price  \
# 1310  Branding Combo Kit :24" Vinyl Cutter Plotter +...       100999.0
# 1846  Smartisan Nut Pro 2 5.99 Inch 6GB RAM 128GB RO...        96839.0
# 1362               LCDTouch Screen For Sony Xperia 5 IV        57895.0
# 1263  Wireless Air Compression Leg Massager Recharge...        51994.0
# 677   LG 43UP7750 - 43" 4K UHD Smart Frameless LED T...        49499.0
# 1871  8 In 1 Combo Heat Press Machine Coffee Magic M...        49499.0
# 1058  3840 X 2160 UHD 40 Pin LCD Screen And Digitize...        48260.0
# 1770  NEO Gleam Modern Led Ceiling Lihgts For Living...        42772.0
# 8                        Starlink Standard Actuated Kit        39500.0
# 613   7000 Lumens Android 4.4 HD 1080P Bluetooth Wif...        36991.0
#
#       Old price  Discount                                               Link
# 1310   129999.0      22.0  /generic-branding-combo-kit-24-vinyl-cutter-pl...
# 1846   193677.0      50.0  /smartisan-nut-pro-2-5.99-inch-6gb-ram-128gb-r...
# 1362    82719.0      30.0  /generic-lcdtouch-screen-for-sony-xperia-5-iv-...
# 1263    89661.0      42.0  /generic-wireless-air-compression-leg-massager...
# 677     89999.0      45.0  /lg-43up7750-43-4k-uhd-smart-frameless-led-tv-...
# 1871    64999.0      24.0  /generic-8-in-1-combo-heat-press-machine-coffe...
# 1058    80395.0      40.0  /generic-3840-x-2160-uhd-40-pin-lcd-screen-and...
# 1770    73704.0      42.0  /generic-neo-gleam-modern-led-ceiling-lihgts-f...
# 8      100000.0      61.0     /starlink-standard-actuated-kit-190334730.html
# 613     73874.0      50.0  /generic-7000-lumens-android-4.4-hd-1080p-blue...

# %%
# 10 cheapest products
products.sort_values(by = 'Current price', ascending=True).head(10)
# Out:
#                                               Item name  Current price  \
# 1180  Nail Sticker Detachable Waterproof PET Nail Ar...           74.0
# 1415            2Pcs/Set Adjustable Couple Rings-Golden           81.0
# 1129  12Pcs Cable Protector Solid Color Flexible Sil...           95.0
# 1070  Kitchen Bathroom Sink Sewer Strainer Filter Ne...          114.0
# 343            Travel Power Adaptor With UK Socket Plug          116.0
# 632   Fashion Finger Ring   Geometric Shape Wedding ...          119.5
# 717   ABS Reed Strength 2.5 For Alto Eb Saxophone Sa...          120.0
# 1079  6 Pairs 12 PCS 3.8mm Soft Silicone In-Ear Earp...          120.0
# 1137  10Pcs Nail Art Sanding Buffer Buffing Block Po...          125.0
# 996   Pull Fuel Tank Pointer To Full Hellaflush Refl...          126.0
#
#       Old price  Discount                                               Link
# 1180      148.0      50.0  /generic-nail-sticker-detachable-waterproof-pe...
# 1415      159.0      49.0  /generic-2pcsset-adjustable-couple-rings-golde...
# 1129      190.0      50.0  /generic-12pcs-cable-protector-solid-color-fle...
# 1070      224.0      49.0  /generic-kitchen-bathroom-sink-sewer-strainer-...
# 343       200.0      42.0  /generic-travel-power-adaptor-with-uk-socket-p...
# 632       179.0      34.0  /fashion-finger-ring-geometric-shape-wedding-c...
# 717       228.0      47.0  /generic-abs-reed-strength-2.5-for-alto-eb-sax...
# 1079      227.0      47.0  /generic-6-pairs-12-pcs-3.8mm-soft-silicone-in...
# 1137      250.0      50.0  /generic-10pcs-nail-art-sanding-buffer-buffing...
# 996       193.0      35.0  /generic-pull-fuel-tank-pointer-to-full-hellaf...

# %%
# 10 prices with the highest discount
products.sort_values(by = 'Discount', ascending=False).head(10)
# Out:
#                                               Item name  Current price  \
# 1645  Fashion African Small Curly Wig, Female Short ...         1199.0
# 104   Fashion ELEGANT  Men's  PURE Leather Loafer Sh...         1214.0
# 1231  Kitchen Organizer Supplies Fridge Storage Rack...          350.0
# 1354  Flangesio Popular Flip Flops Men Shoes High Qu...         2340.0
# 8                        Starlink Standard Actuated Kit        39500.0
# 310   Fashion Large Capacity Butterfly Tote Bag Wome...          650.0
# 449     Geemy Professional Hair/Shaving Machine/kinyozi         1300.0
# 1640                      Outdoor Solar Post Gate Light         2400.0
# 245   Fashion Eyeshadow Eye Shadow Pans Palette Eye-...          429.0
# 1825          Tripod Stand For Camera/Phone,Up To 168CM         2449.0
#
#       Old price  Discount                                               Link
# 1645     4100.0      71.0  /fashion-african-small-curly-wig-female-short-...
# 104      3099.0      67.0  /fashion-elegant-mens-pure-leather-loafer-shoe...
# 1231      999.0      65.0  /generic-kitchen-organizer-supplies-fridge-sto...
# 1354     6500.0      64.0  /flangesio-popular-flip-flops-men-shoes-high-q...
# 8      100000.0      61.0     /starlink-standard-actuated-kit-190334730.html
# 310      1500.0      57.0  /fashion-large-capacity-butterfly-tote-bag-wom...
# 449      3000.0      57.0  /geemy-professional-hairshaving-machinekinyozi...
# 1640     5500.0      56.0  /generic-outdoor-solar-post-gate-light-7241176...
# 245       982.0      56.0  /fashion-eyeshadow-eye-shadow-pans-palette-eye...
# 1825     5580.0      56.0  /long-neck-car-phone-holder-universal-mpg32808...
